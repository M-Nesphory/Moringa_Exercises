# %% [markdown]
# # Pandas

# %%
#Import pandas and numpy
import pandas as pd
import numpy as np # used for mathematical computation # built on top of numpy

# %% [markdown]
# Data stractures used in pandas
# 1. pandas series
# 2. pandas data Frame

# %%
list1 = ['Boat', 'Car', 'Ship']
series1 = pd.Series(list1)
type(series1)

# %%
list2 = [5, 7, 10]
series2 = pd.Series(list2)
print(series2)
# Out:
# 0     5
# 1     7
# 2    10
# dtype: int64

# %%
data = [('Boat', 5), ('Car', 7), ('Ship', 10)]
df = pd. DataFrame(data, columns=('Item', 'Price'))
df
# Out:
#    Item  Price
# 0  Boat      5
# 1   Car      7
# 2  Ship     10

# %%
type(df['Price'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Reading from files

# %%
#Loading the dataset #excel dataset
df = pd.read_excel("/content/Sample Superstore.xlsx")

# %% [markdown]
# ## Writing to files

# %%
#saving the file to csv # use to_csv() and set index = False
df.to_csv("super.csv")

# %% [markdown]
# ## Dataframe basics

# %%
#setting the default data view # pd.set_option("display.max_columns", 500)
pd.set_option("display.max_columns", 500)

# %%
#Displaying the top 3 rows # use head()
df.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
#
#   Product Sub-Category Product Container  \
# 0               Labels         Small Box
# 1  Pens & Art Supplies          Wrap Bag
# 2                Paper         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
#
#    Profit  Quantity ordered new  Sales  Order ID
# 0    1.32                     2   5.90     88525
# 1    4.56                     4  13.01     88522
# 2  -47.64                     7  49.92     88523

# %%
#Displaying the last 3 rows # use tail()
df.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 9421  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422  Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423  Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424   Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425   Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#      Region State or Province        City  Postal Code Order Date  Ship Date  \
# 9421   East     West Virginia  Charleston        25314 2013-05-14 2013-05-15
# 9422   East     West Virginia  Charleston        25314 2013-05-14 2013-05-14
# 9423   East     West Virginia  Charleston        25314 2013-09-12 2013-09-14
# 9424   West           Wyoming    Cheyenne        82001 2010-02-08 2010-02-11
# 9425   West           Wyoming    Cheyenne        82001 2013-09-12 2013-09-14
#
#            Profit  Quantity ordered new    Sales Order ID
# 9421   137.860000                    13   447.87    87532
# 9422   -39.070000                     3    13.23    87532
# 9423 -1225.029097                     4  2215.93    87533
# 9424   349.485000                     5   506.50    87530
# 9425    78.062400                    23   172.48    87533
#
# [5 rows x 24 columns]

# %%
#Displaying 3 random rows #use sample()
df.sample(3, random_state= 40)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 4010   21821            Low      0.02       19.99          11.17         1503
# 8467   19739         Medium      0.00      137.48          32.18         3076
# 5010   21695       Critical      0.04      279.48          35.00         1847
#
#       Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 4010      Leo Riley     Regular Air   Small Business        Furniture  ...
# 8467    Peter Hardy  Delivery Truck   Small Business        Furniture  ...
# 5010  Glen Horowitz     Regular Air      Home Office  Office Supplies  ...
#
#        Region State or Province                City  Postal Code Order Date  \
# 4010  Central          Illinois  Country Club Hills        60478 2012-06-04
# 8467     East              Ohio                Stow        44224 2010-07-07
# 5010     East          New York            Holbrook        11741 2013-06-19
#
#       Ship Date    Profit  Quantity ordered new    Sales Order ID
# 4010 2012-06-06   17.0292                     1    24.68    89195
# 8467 2010-07-08 -203.2700                     2   296.75    88241
# 5010 2013-06-21  205.5600                    13  3640.81    86048
#
# [3 rows x 24 columns]

# %%
#checking the columns # use columns attribute
df.columns # features, attribute
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#checking the index # use df.index
df.index
# Out:
# RangeIndex(start=0, stop=9426, step=1)

# %% [markdown]
# ## Dataframe summary

# %%
#Checking the data Summary # use info(), we can also use info(verbose=False)
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Columns: 24 entries, Row ID to Order ID
# dtypes: datetime64[ns](2), float64(6), int64(5), object(11)
# memory usage: 1.7+ MB

# %%
#Checking concise Descriptive statistics for numerical variables# use df.describe()
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# 25%               0.380000  29406.000000            2011-03-07 06:00:00
# 50%               0.520000  52302.000000            2012-04-08 00:00:00
# 75%               0.590000  78516.000000            2013-03-26 00:00:00
# max               0.850000  99362.000000            2013-12-31 00:00:00
# std               0.135229  29374.597802                            NaN
#
#                            Ship Date        Profit  Quantity ordered new  \
# count                           9426   9426.000000           9426.000000
# mean   2012-03-07 19:16:18.485041408    139.236410             13.798430
# min              2010-01-02 00:00:00 -16476.838000              1.000000
# 25%              2011-03-09 00:00:00    -74.017375              5.000000
# 50%              2012-04-09 00:00:00      2.567600             10.000000
# 75%              2013-03-28 00:00:00    140.243850             17.000000
# max              2014-01-17 00:00:00  16332.414000            170.000000
# std                              NaN    998.486483             15.107688
#
#                Sales      Order ID
# count    9426.000000   9426.000000
# mean      949.706272  82318.489073
# min         1.320000      6.000000
# 25%        61.282500  86737.250000
# 50%       203.455000  88344.500000
# 75%       776.402500  89987.750000
# max    100119.160000  91591.000000
# std      2598.019818  19149.448857

# %%
#Checking concise Descriptive statistics for categorical variables# use df['col'].describe()
df['Region'].describe()
# Out:
# count        9426
# unique          4
# top       Central
# freq         2899
# Name: Region, dtype: object

# %%
#checking the number of variables and records, use df.shape,   or len(df)
df.shape, len(df)
# Out:
# ((9426, 24), 9426)

# %% [markdown]
# ## Subsetting Columns
#
# This is the act of selecting  a few columns from the entire dataframe.

# %%
#selcting the specific columns# use df[['col1', 'col2', 'col3']] e.g. selsct Order Date, Product Date, and ship mode
data = df[['Region', 'Unit Price', 'Sales']]
data.head()
# Out:
#     Region  Unit Price    Sales
# 0  Central        2.88     5.90
# 1     West        2.84    13.01
# 2     West        6.68    49.92
# 3     West        5.68    41.64
# 4     West      205.99  1446.67

# %%
# we can use slicing as well e.g. df[df.columns[:5]]
df[df.columns[:5]]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost
# 0      18606  Not Specified      0.01        2.88           0.50
# 1      20847           High      0.01        2.84           0.93
# 2      23086  Not Specified      0.03        6.68           6.15
# 3      23087  Not Specified      0.01        5.68           3.60
# 4      23088  Not Specified      0.00      205.99           2.50
# ...      ...            ...       ...         ...            ...
# 9421   20275       Critical      0.06       35.89          14.72
# 9422   20276       Critical      0.00        3.34           7.49
# 9423   24491  Not Specified      0.08      550.98          45.70
# 9424   25914           High      0.10      105.98          13.99
# 9425   24492  Not Specified      0.09        7.78           2.50
#
# [9426 rows x 5 columns]

# %%
#Using list comprehnsion e.g df[[c for c in df.columns]]
df[[c for c in df.columns]]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %% [markdown]
# ## Select dtypes

# %%
# Selecting the numerical variables use df.select_dtypes(), include what you want to select as an argument
df.select_dtypes(include='int')# you can change int to object and rerun the code.
# Out:
#       Row ID  Customer ID  Postal Code  Quantity ordered new  Order ID
# 0      18606            2        60101                     2     88525
# 1      20847            3        98221                     4     88522
# 2      23086            3        98221                     7     88523
# 3      23087            3        98221                     7     88523
# 4      23088            3        98221                     8     88523
# ...      ...          ...          ...                   ...       ...
# 9421   20275         3402        25314                    13     87532
# 9422   20276         3402        25314                     3     87532
# 9423   24491         3402        25314                     4     87533
# 9424   25914         3403        82001                     5     87530
# 9425   24492         3403        82001                    23     87533
#
# [9426 rows x 5 columns]

# %% [markdown]
# ## Select as series vs dataframe

# %%
#checking the series, use df['Col name']
series3 = df['Region']
type(series3)
# Out:
# pandas.core.series.Series

# %%
#making the above as a dataframe , use df[['col name']]
fr = df[['Region']]
type(fr)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## loc and iloc
#
# We can use loc(variable location), and iloc(index location) to access the variables as well

# %% [markdown]
# ### iloc

# %%
df.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
# 2 -47.64                     7  49.92    88523
#
# [3 rows x 24 columns]

# %%
# getting the value using iloc e.g df.iloc[1, 1]
df.iloc[2,2]
# Out:
# 0.03

# %%
#slicing e.g df.iloc[:5, :5]
df.iloc[:5,:5]
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost
# 0   18606  Not Specified      0.01        2.88           0.50
# 1   20847           High      0.01        2.84           0.93
# 2   23086  Not Specified      0.03        6.68           6.15
# 3   23087  Not Specified      0.01        5.68           3.60
# 4   23088  Not Specified      0.00      205.99           2.50

# %%
#Getting specific row e.g df.iloc[5], we can present our result in dataframe formart as well
df.iloc[[5]]
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 5   23597         Medium      0.09       55.48           14.3            3
#
#    Customer Name    Ship Mode Customer Segment Product Category  ... Region  \
# 5  Bonnie Potter  Express Air        Corporate  Office Supplies  ...   West
#
#   State or Province       City  Postal Code Order Date  Ship Date     Profit  \
# 5        Washington  Anacortes        98221 2011-11-09 2011-11-11  1388.0523
#
#    Quantity ordered new    Sales Order ID
# 5                    37  2011.67    88524
#
# [1 rows x 24 columns]

# %%
#Checking the index 1 columns e.g df.iloc[:, 1]

# %%
#getting index 1 and 2 columns, e.g  df.iloc[:, [1, 2]]

# %% [markdown]
# Loc
#
# we use loc when we want to select the variable by the name

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#subsetting  2 columns df.loc[:, ['col1', 'col2']]
df.loc[:, ['Discount', 'Sales']]
# Out:
#       Discount    Sales
# 0         0.01     5.90
# 1         0.01    13.01
# 2         0.03    49.92
# 3         0.01    41.64
# 4         0.00  1446.67
# ...        ...      ...
# 9421      0.06   447.87
# 9422      0.00    13.23
# 9423      0.08  2215.93
# 9424      0.10   506.50
# 9425      0.09   172.48
#
# [9426 rows x 2 columns]

# %% [markdown]
# #### loc filter expressions
#
# we can use loc filter to get specific records

# %%
#Get the records of a specific value e.g  df.loc[df['Region'] == 'West']
df.loc[df['Region']=='West']
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 5      23597         Medium      0.09       55.48          14.30            3
# ...      ...            ...       ...         ...            ...          ...
# 9390   23658         Medium      0.00       12.28           4.86         3394
# 9391   22578  Not Specified      0.04        6.84           8.37         3394
# 9392   22579  Not Specified      0.07      125.99           7.69         3394
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#       Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 1     Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2     Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3     Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4     Bonnie Potter  Express Air        Corporate       Technology  ...
# 5     Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# ...             ...          ...              ...              ...  ...
# 9390  Julia Padgett  Express Air         Consumer  Office Supplies  ...
# 9391  Julia Padgett  Regular Air         Consumer  Office Supplies  ...
# 9392  Julia Padgett  Regular Air         Consumer       Technology  ...
# 9424  Tammy Buckley  Express Air         Consumer        Furniture  ...
# 9425  Tammy Buckley  Express Air         Consumer  Office Supplies  ...
#
#      Region State or Province       City  Postal Code Order Date  Ship Date  \
# 1      West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2      West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3      West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4      West        Washington  Anacortes        98221 2011-07-27 2011-07-27
# 5      West        Washington  Anacortes        98221 2011-11-09 2011-11-11
# ...     ...               ...        ...          ...        ...        ...
# 9390   West        Washington   Puyallup        98373 2012-03-10 2012-03-11
# 9391   West        Washington   Puyallup        98373 2013-08-19 2013-08-20
# 9392   West        Washington   Puyallup        98373 2013-08-19 2013-08-20
# 9424   West           Wyoming   Cheyenne        82001 2010-02-08 2010-02-11
# 9425   West           Wyoming   Cheyenne        82001 2013-09-12 2013-09-14
#
#            Profit  Quantity ordered new    Sales Order ID
# 1        4.560000                     4    13.01    88522
# 2      -47.640000                     7    49.92    88523
# 3      -30.510000                     7    41.64    88523
# 4      998.202300                     8  1446.67    88523
# 5     1388.052300                    37  2011.67    88524
# ...           ...                   ...      ...      ...
# 9390   115.216200                    13   166.98    87911
# 9391  -117.252960                    24   161.87    87913
# 9392   139.258512                    10   995.95    87913
# 9424   349.485000                     5   506.50    87530
# 9425    78.062400                    23   172.48    87533
#
# [2284 rows x 24 columns]

# %%
#we can use loc to get records of more than one specific variables
df.loc[(df['Product Category'] == 'Furniture') & (df['Order Date'] == '2010-07-07')]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1639   25539       Critical      0.03       14.20           5.30          619
# 4805   19419            Low      0.03        5.08           2.03         1781
# 8467   19739         Medium      0.00      137.48          32.18         3076
# 8492    1739         Medium      0.00      137.48          32.18         3079
#
#       Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 1639  Howard Rogers     Regular Air         Consumer        Furniture  ...
# 4805   Jackie Capps     Regular Air      Home Office        Furniture  ...
# 8467    Peter Hardy  Delivery Truck   Small Business        Furniture  ...
# 8492  Andrew Levine  Delivery Truck   Small Business        Furniture  ...
#
#        Region State or Province          City  Postal Code Order Date  \
# 1639  Central          Michigan     Southgate        48195 2010-07-07
# 4805     West        California    San Carlos        94070 2010-07-07
# 8467     East              Ohio          Stow        44224 2010-07-07
# 8492     East      Pennsylvania  Philadelphia        19112 2010-07-07
#
#       Ship Date    Profit  Quantity ordered new    Sales Order ID
# 1639 2010-07-08  107.0200                    14   205.98    88196
# 4805 2010-07-12   15.1524                     4    21.96    89858
# 8467 2010-07-08 -203.2700                     2   296.75    88241
# 8492 2010-07-08 -203.2700                    10  1483.76    12480
#
# [4 rows x 24 columns]

# %%
#we can use tilde(~) to get the records of those not represented in the code
df.loc[~((df['Product Category'] == 'Furniture') & (df['Order Date'] == '2010-07-07'))]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9422 rows x 24 columns]

# %% [markdown]
# ## query
#
# Query method is another way of getting specific records

# %%
#getting specific records e.g df.query('Sales >200 and Region == "West"')
df.query('Sales >200 and Region == "West"')
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 4      23088  Not Specified      0.00      205.99           2.50            3
# 5      23597         Medium      0.09       55.48          14.30            3
# 6      25549            Low      0.08      120.97          26.30            3
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 9      24782           High      0.01       90.24           0.99            6
# ...      ...            ...       ...         ...            ...          ...
# 9378   19464  Not Specified      0.03       95.99          35.00         3388
# 9384   18640         Medium      0.08      125.99           7.69         3393
# 9386   18429           High      0.03      160.98          30.00         3393
# 9392   22579  Not Specified      0.07      125.99           7.69         3394
# 9424   25914           High      0.10      105.98          13.99         3403
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 4      Bonnie Potter     Express Air        Corporate       Technology  ...
# 5      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 6      Bonnie Potter  Delivery Truck        Corporate       Technology  ...
# 7     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 9       Dwight Hwang     Regular Air      Home Office  Office Supplies  ...
# ...              ...             ...              ...              ...  ...
# 9378   Aaron Shaffer     Regular Air        Corporate  Office Supplies  ...
# 9384    Irene Murphy     Regular Air         Consumer       Technology  ...
# 9386    Irene Murphy  Delivery Truck         Consumer        Furniture  ...
# 9392   Julia Padgett     Regular Air         Consumer       Technology  ...
# 9424   Tammy Buckley     Express Air         Consumer        Furniture  ...
#
#      Region State or Province         City  Postal Code Order Date  Ship Date  \
# 4      West        Washington    Anacortes        98221 2011-07-27 2011-07-27
# 5      West        Washington    Anacortes        98221 2011-11-09 2011-11-11
# 6      West        Washington    Anacortes        98221 2013-07-01 2013-07-08
# 7      West        California  San Gabriel        91776 2010-12-13 2010-12-15
# 9      West        California     San Jose        95123 2011-05-26 2011-05-26
# ...     ...               ...          ...          ...        ...        ...
# 9378   West        California    Fairfield        94533 2010-11-11 2010-11-12
# 9384   West        Washington      Pullman        99163 2010-04-29 2010-04-30
# 9386   West        Washington      Pullman        99163 2012-08-21 2012-08-23
# 9392   West        Washington     Puyallup        98373 2013-08-19 2013-08-20
# 9424   West           Wyoming     Cheyenne        82001 2010-02-08 2010-02-11
#
#            Profit  Quantity ordered new    Sales Order ID
# 4      998.202300                     8  1446.67    88523
# 5     1388.052300                    37  2011.67    88524
# 6     1001.445300                    12  1451.37    88526
# 7     4390.366500                    12  6362.85    90193
# 9     1045.467300                    16  1515.17    90194
# ...           ...                   ...      ...      ...
# 9378    67.012000                     9   894.64    90154
# 9384   374.625000                     7   710.36    87908
# 9386   836.703200                    11  1852.24    87912
# 9392   139.258512                    10   995.95    87913
# 9424   349.485000                     5   506.50    87530
#
# [1154 rows x 24 columns]

# %%
#Another different way of using query method
#min_sale = 600
#df.query('Sales > @min_Sale and (Region == "West")')
#----------------------------------------------
min_Sale = 600
query_expression = 'Sales > {} and (Region == "West")'.format(min_Sale)
df.query(query_expression)

# %% [markdown]
# ## Summary Statistics
#
# This is when we want to infer or get more information on the variable performance

# %%
#we can use min, max, mean, std, and quantile
df['Sales'].min()
# Out:
# 1.32

# %%
df['Sales'].max()
# Out:
# 100119.16

# %%
round(df['Sales'].mean(),1)
# Out:
# 949.7

# %%
df['Sales'].std()
# Out:
# 2598.019818273428

# %%
df['Sales'].quantile([.25, .5,.75])
# Out:
# 0.25     61.2825
# 0.50    203.4550
# 0.75    776.4025
# Name: Sales, dtype: float64

# %% [markdown]
# ## agg
#
# This is used when we need to get summary statistics of more than 1 at ago.

# %%
# Getting  min, mean, max of 3 variables('Sales','Discount', 'Profit'), use  df[['col1','col2', 'col3']].agg(['mean', 'min', 'max'])
df[['Discount','Profit', 'Sales']].agg(['mean', 'min', 'max'])
# Out:
#       Discount       Profit          Sales
# mean  0.049628    139.23641     949.706272
# min   0.000000 -16476.83800       1.320000
# max   0.250000  16332.41400  100119.160000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#anaother way of doing the above

df[['Sales','Discount', 'Profit']].agg(
    {
        'Sales': ['min', 'max'],
        'Discount': ['mean'],
        'Profit': ['min', 'max']
    }
)
# Out:
#           Sales  Discount     Profit
# min        1.32       NaN -16476.838
# max   100119.16       NaN  16332.414
# mean        NaN  0.049628        NaN

# %% [markdown]
# ## Summarize categoricals
#
# we use different way to categorize categorical variables

# %%
#use unique to see the unique values in the variable, use  df['col'].unique()
df['Region'].unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
#nunique is used to get the number, use  df['col'].nunique()
df['Region'].nunique()
# Out:
# 4

# %%
#Value count is used to get the number of occurances use df['col'].value_counts()
df[['Product Category']].value_counts()
# Out:
# Product Category
# Office Supplies     5181
# Technology          2312
# Furniture           1933
# Name: count, dtype: int64

# %%
# valuse counts for 2 variable, return dataframe  df[['col1', 'col2']].value_counts()
df[['Product Category','Region']].value_counts()
# Out:
# Product Category  Region
# Office Supplies   Central    1559
#                   East       1272
#                   West       1251
#                   South      1099
# Technology        Central     717
# Furniture         Central     623
# Technology        West        572
#                   East        538
#                   South       485
# Furniture         East        479
#                   West        461
#                   South       370
# Name: count, dtype: int64

# %%
# we use reset index so that the result starts from index zero use df[['col1', 'col2']].value_counts().reset_index()
df[['Product Category','Region']].value_counts().reset_index()
# Out:
#    Product Category   Region  count
# 0   Office Supplies  Central   1559
# 1   Office Supplies     East   1272
# 2   Office Supplies     West   1251
# 3   Office Supplies    South   1099
# 4        Technology  Central    717
# 5         Furniture  Central    623
# 6        Technology     West    572
# 7        Technology     East    538
# 8        Technology    South    485
# 9         Furniture     East    479
# 10        Furniture     West    461
# 11        Furniture    South    370

# %% [markdown]
# ## shift, cumsum

# %%
df[['Sales']].head()
# Out:
#      Sales
# 0     5.90
# 1    13.01
# 2    49.92
# 3    41.64
# 4  1446.67

# %%
#shift is commonly used in time series , use df[['col']].shift(1)
df['_sales'] = df[['Sales']].shift(1)

# %%
#shift last value df[['col']].shift(-1)
df[['Sales']].shift(-1)
# Out:
#         Sales
# 0       13.01
# 1       49.92
# 2       41.64
# 3     1446.67
# 4     2011.67
# ...       ...
# 9421    13.23
# 9422  2215.93
# 9423   506.50
# 9424   172.48
# 9425      NaN
#
# [9426 rows x 1 columns]

# %%
#fill up the shitfed value, use df[['col']].shift(3, fill_value=100)
df[['Sales']].shift(1, fill_value= 00)
# Out:
#         Sales
# 0        0.00
# 1        5.90
# 2       13.01
# 3       49.92
# 4       41.64
# ...       ...
# 9421  1969.31
# 9422   447.87
# 9423    13.23
# 9424  2215.93
# 9425   506.50
#
# [9426 rows x 1 columns]

# %%
#summing up the sum values, use df[['col']].cumsum()
df[['Sales']].cumsum()
# Out:
#            Sales
# 0           5.90
# 1          18.91
# 2          68.83
# 3         110.47
# 4        1557.14
# ...          ...
# 9421  8949023.18
# 9422  8949036.41
# 9423  8951252.34
# 9424  8951758.84
# 9425  8951931.32
#
# [9426 rows x 1 columns]

# %%
#we can also do cummax, and cummin

# %% [markdown]
# ## Rolling methods

# %%
#using Rolling, usse df[['col']].rolling(window=5).mean()
df[['Sales']].rolling(window=3).mean()
# Out:
#             Sales
# 0             NaN
# 1             NaN
# 2       22.943333
# 3       34.856667
# 4      512.743333
# ...           ...
# 9421  1004.510000
# 9422   810.136667
# 9423   892.343333
# 9424   911.886667
# 9425   964.970000
#
# [9426 rows x 1 columns]

# %% [markdown]
# ## Groupby
#
# This is used when we want to summarize categorical features based on a certain numerical variable

# %%
# use groupby, use df.groupby('cat_col')[['num_coll']].mean(), e.g region and sales
df.groupby('Region')[['Sales']].mean()
# Out:
#                Sales
# Region
# Central   876.282035
# East     1058.455518
# South     817.475036
# West     1047.039755

# %%
#Using agg() together with groupby e.g df.groupby('cta_col')[['num_col']].agg(['mean', 'min', 'max'])
df.groupby('Region')[['Sales']].agg(["mean", "min"])
# Out:
#                Sales
#                 mean   min
# Region
# Central   876.282035  2.24
# East     1058.455518  1.32
# South     817.475036  2.66
# West     1047.039755  1.62

# %%
#combining two numerical columns
df.groupby('Region')[['Sales', 'Profit']].agg(["mean", "min"])
# Out:
#                Sales            Profit
#                 mean   min        mean         min
# Region
# Central   876.282035  2.24  179.312027 -13706.4640
# East     1058.455518  1.32  164.948094  -4017.6165
# South     817.475036  2.66   53.327120 -16476.8380
# West     1047.039755  1.62  136.098710 -14140.7016

# %% [markdown]
# ## New columns

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies
# 4    Bonnie Potter  Express Air        Corporate       Technology
#
#             Product Sub-Category Product Container  \
# 0                         Labels         Small Box
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
#
#                                      Product Name  Product Base Margin  \
# 0                                        Avery 49                 0.36
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 2                                      Xerox 1968                 0.37
# 3        Acme® Preferred Stainless Steel Scissors                 0.56
# 4                                             V70                 0.59
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales  Order ID
# 0    1.3200                     2     5.90     88525
# 1    4.5600                     4    13.01     88522
# 2  -47.6400                     7    49.92     88523
# 3  -30.5100                     7    41.64     88523
# 4  998.2023                     8  1446.67     88523

# %%
#ctreating a new column,  e.g df['new_col'] = df['Sales'] - df['Profit']
df['Cost'] = df['Sales'] - df['Profit']

# %%
df['Tax'] = df['Sales']/.2

# %%
#Another way of creating new column using assign method, use df=df.assign(colname=expression)
#creating new column using .assign()
df=df.assign(col_2=df["Profit"]/0.3)

# %% [markdown]
# ## Sorting
#
# This is a way of ordering the values either in ascending or descending order

# %%
df.Region.unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
#sort values use  df.sort_values('col'), we can apply argument ascending= False to get the result in descending order
df.sort_values('Region', ascending=False)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
# 2423   18395  Not Specified      0.01       65.99           8.99          922
# 2414   25931       Critical      0.08        5.28           5.66          918
# 2415   25677           High      0.10        8.34           2.64          919
# 2416   19747           High      0.04       40.98           7.20          919
# ...      ...            ...       ...         ...            ...          ...
# 4803   25533            Low      0.08       48.04           7.23         1779
# 4831   18503       Critical      0.08        6.48           8.40         1789
# 4832   18775       Critical      0.05       29.17           6.27         1789
# 4833   18776       Critical      0.03      146.05          80.20         1789
# 4713   25345            Low      0.10        3.95           2.00         1750
#
#          Customer Name       Ship Mode Customer Segment Product Category  \
# 9425     Tammy Buckley     Express Air         Consumer  Office Supplies
# 2423    Dolores Abrams     Express Air   Small Business       Technology
# 2414    Kerry Jernigan     Regular Air         Consumer  Office Supplies
# 2415  Tracy Livingston     Regular Air         Consumer  Office Supplies
# 2416  Tracy Livingston     Regular Air        Corporate  Office Supplies
# ...                ...             ...              ...              ...
# 4803     Samantha Hall     Regular Air         Consumer  Office Supplies
# 4831       Allan Green     Regular Air         Consumer  Office Supplies
# 4832       Allan Green     Regular Air         Consumer  Office Supplies
# 4833       Allan Green  Delivery Truck         Consumer        Furniture
# 4713   Constance Britt     Regular Air         Consumer  Office Supplies
#
#                 Product Sub-Category Product Container  \
# 9425                       Envelopes         Small Box
# 2423    Telephones and Communication         Small Box
# 2414                           Paper         Small Box
# 2415   Scissors, Rulers and Trimmers        Small Pack
# 2416                      Appliances         Small Box
# ...                              ...               ...
# 4803                           Paper         Small Box
# 4831                           Paper         Small Box
# 4832  Binders and Binder Accessories         Small Box
# 4833                          Tables         Jumbo Box
# 4713                    Rubber Bands          Wrap Bag
#
#                                            Product Name  Product Base Margin  \
# 9425                      Staples #10 Colored Envelopes                 0.38
# 2423                                               5180                 0.56
# 2414  Xerox 4200 Series MultiUse Premium Copy Paper ...                 0.40
# 2415               Acme® Elite Stainless Steel Scissors                 0.59
# 2416    Kensington 6 Outlet SmartSocket Surge Protector                 0.60
# ...                                                 ...                  ...
# 4803                                         Xerox 1885                 0.37
# 4831                                          Xerox 212                 0.37
# 4832                           Binding Machine Supplies                 0.37
# 4833                              BPI Conference Tables                 0.71
# 4713    Advantus Map Pennant Flags and Round Head Tacks                 0.53
#
#        Region State or Province              City  Postal Code Order Date  \
# 9425     West           Wyoming          Cheyenne        82001 2013-09-12
# 2423     West        California  Rancho Cucamonga        91730 2010-05-20
# 2414     West        California  Rancho Cucamonga        91730 2013-10-25
# 2415     West        California           Redding        96003 2010-04-12
# 2416     West        California           Redding        96003 2012-02-20
# ...       ...               ...               ...          ...        ...
# 4803  Central              Iowa              Ames        50010 2012-04-09
# 4831  Central          Missouri        Wentzville        63385 2011-08-17
# 4832  Central          Missouri        Wentzville        63385 2011-12-24
# 4833  Central          Missouri        Wentzville        63385 2011-12-24
# 4713  Central          Oklahoma      Midwest City        73110 2011-02-02
#
#       Ship Date    Profit  Quantity ordered new   Sales  Order ID        col_2
# 9425 2013-09-14   78.0624                    23  172.48     87533   260.208000
# 2423 2010-05-21  396.9720                    14  782.00     87135  1323.240000
# 2414 2013-10-26 -107.2000                    20  105.88     90499  -357.333333
# 2415 2010-04-12   -6.3400                     6   47.95     90492   -21.133333
# 2416 2012-02-21  275.5000                    12  483.59     90495   918.333333
# ...         ...       ...                   ...     ...       ...          ...
# 4803 2012-04-11  315.4956                    10  457.24     89948  1051.652000
# 4831 2011-08-18 -110.5052                    19  116.98     88259  -368.350667
# 4832 2011-12-26  411.1986                    20  595.94     88261  1370.662000
# 4833 2011-12-25 -334.0935                     6  895.53     88261 -1113.645000
# 4713 2011-02-09   -2.3400                     1    5.70     87247    -7.800000
#
# [9426 rows x 25 columns]

# %%
#resetting the index, use df[['col1', 'col2', 'col3']].sort_values('col3', ascending=False).reset_index(drop=True)
df[['Region',"Product Name","Sales"]].sort_values("Sales", ascending=False)
# Out:
#        Region                                       Product Name      Sales
# 8461     West  Riverside Palais Royal Lawyers Bookcase, Royal...  100119.16
# 7013     West              Canon imageCLASS 2200 Advanced Copier   50332.66
# 7040     East                      Canon PC1080F Personal Copier   48418.58
# 4642     East  Fellowes PB500 Electric Punch Plastic Comb Bin...   45737.33
# 1418     West               Lexmark 4227 Plus Dot Matrix Printer   43046.20
# ...       ...                                                ...        ...
# 1066     West                                 Round Ring Binders       2.25
# 7511  Central                                Binder Clips by OIC       2.24
# 2770     East                                Binder Clips by OIC       1.65
# 932      West                                Bagged Rubber Bands       1.62
# 4369     East                                    OIC Thumb-Tacks       1.32
#
# [9426 rows x 3 columns]

# %% [markdown]
# ## Missing data
#
# This is how we can check and fix null values

# %%
#checking missing values, use df.isna(), add .sum()a better result
df.isna().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# col_2                    0
# dtype: int64

# %%
#fixing the null values  by dropping the rows df.dropna(subset=['col with missing value']), or just df.dropna() for entire dataframe
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# col_2                   0
# dtype: int64

# %%
#filling up the missing value with specific value, use df[['col1', 'col2', 'col3']].fillna(0)
df[['Region', 'Product Name']].fillna('unknown')

# %%
#Filling with the mean of the column, use df['col1'].fillna(df['col1'].mean())
df['Sale'].fillna(df['Sales'].mean())

# %% [markdown]
# ## Concat
#
# concat is used when all the variables as similar

# %%
# create 2 dataframe
df1 = df.query('Region == "West"').copy()
df2 = df.query('Region == "East"').copy()

# %%
#concat, use pd.concat([df1, df2])
df3= pd.concat([df1,df2])
df3.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
# 5   23597         Medium      0.09       55.48          14.30            3
#
#    Customer Name    Ship Mode Customer Segment Product Category  \
# 1  Bonnie Potter  Express Air        Corporate  Office Supplies
# 2  Bonnie Potter  Express Air        Corporate  Office Supplies
# 3  Bonnie Potter  Regular Air        Corporate  Office Supplies
# 4  Bonnie Potter  Express Air        Corporate       Technology
# 5  Bonnie Potter  Express Air        Corporate  Office Supplies
#
#             Product Sub-Category Product Container  \
# 1            Pens & Art Supplies          Wrap Bag
# 2                          Paper         Small Box
# 3  Scissors, Rulers and Trimmers        Small Pack
# 4   Telephones and Communication         Small Box
# 5                          Paper         Small Box
#
#                                      Product Name  Product Base Margin Region  \
# 1  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54   West
# 2                                      Xerox 1968                 0.37   West
# 3        Acme® Preferred Stainless Steel Scissors                 0.56   West
# 4                                             V70                 0.59   West
# 5                                       Xerox 194                 0.37   West
#
#   State or Province       City  Postal Code Order Date  Ship Date     Profit  \
# 1        Washington  Anacortes        98221 2010-07-07 2010-07-08     4.5600
# 2        Washington  Anacortes        98221 2011-07-27 2011-07-28   -47.6400
# 3        Washington  Anacortes        98221 2011-07-27 2011-07-28   -30.5100
# 4        Washington  Anacortes        98221 2011-07-27 2011-07-27   998.2023
# 5        Washington  Anacortes        98221 2011-11-09 2011-11-11  1388.0523
#
#    Quantity ordered new    Sales  Order ID     col_2
# 1                     4    13.01     88522    15.200
# 2                     7    49.92     88523  -158.800
# 3                     7    41.64     88523  -101.700
# 4                     8  1446.67     88523  3327.341
# 5                    37  2011.67     88524  4626.841

# %%
#we can resset the index then concat as well
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# %%
#concat, use pd.concat([df1, df2], axis=1)
df_concat=pd.concat([df1,df2], axis=1)
df_concat.head()
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0  20847.0           High      0.01        2.84           0.93          3.0
# 1  23086.0  Not Specified      0.03        6.68           6.15          3.0
# 2  23087.0  Not Specified      0.01        5.68           3.60          3.0
# 3  23088.0  Not Specified      0.00      205.99           2.50          3.0
# 4  23597.0         Medium      0.09       55.48          14.30          3.0
#
#    Customer Name    Ship Mode Customer Segment Product Category  \
# 0  Bonnie Potter  Express Air        Corporate  Office Supplies
# 1  Bonnie Potter  Express Air        Corporate  Office Supplies
# 2  Bonnie Potter  Regular Air        Corporate  Office Supplies
# 3  Bonnie Potter  Express Air        Corporate       Technology
# 4  Bonnie Potter  Express Air        Corporate  Office Supplies
#
#             Product Sub-Category Product Container  \
# 0            Pens & Art Supplies          Wrap Bag
# 1                          Paper         Small Box
# 2  Scissors, Rulers and Trimmers        Small Pack
# 3   Telephones and Communication         Small Box
# 4                          Paper         Small Box
#
#                                      Product Name  Product Base Margin Region  \
# 0  SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54   West
# 1                                      Xerox 1968                 0.37   West
# 2        Acme® Preferred Stainless Steel Scissors                 0.56   West
# 3                                             V70                 0.59   West
# 4                                       Xerox 194                 0.37   West
#
#   State or Province       City  Postal Code Order Date  Ship Date     Profit  \
# 0        Washington  Anacortes      98221.0 2010-07-07 2010-07-08     4.5600
# 1        Washington  Anacortes      98221.0 2011-07-27 2011-07-28   -47.6400
# 2        Washington  Anacortes      98221.0 2011-07-27 2011-07-28   -30.5100
# 3        Washington  Anacortes      98221.0 2011-07-27 2011-07-27   998.2023
# 4        Washington  Anacortes      98221.0 2011-11-09 2011-11-11  1388.0523
#
#    Quantity ordered new    Sales  Order ID     col_2  Row ID Order Priority  \
# 0                   4.0    13.01   88522.0    15.200   21866           High
# 1                   7.0    49.92   88523.0  -158.800   20876         Medium
# 2                   7.0    41.64   88523.0  -101.700   20877         Medium
# 3                   8.0  1446.67   88523.0  3327.341   22241       Critical
# 4                  37.0  2011.67   88524.0  4626.841   21776       Critical
#
#    Discount  Unit Price  Shipping Cost  Customer ID           Customer Name  \
# 0      0.05       12.28           4.86            7               Leon Gill
# 1      0.08      140.98          36.09            8          Melanie Garner
# 2      0.10      286.85          61.76            9        Lorraine Houston
# 3      0.06       15.57           1.39           10  Meredith Norris Thomas
# 4      0.06        9.48           7.29           11           Marcus Dunlap
#
#         Ship Mode Customer Segment Product Category Product Sub-Category  \
# 0     Regular Air      Home Office  Office Supplies                Paper
# 1  Delivery Truck      Home Office        Furniture            Bookcases
# 2  Delivery Truck      Home Office        Furniture               Tables
# 3     Regular Air      Home Office  Office Supplies            Envelopes
# 4     Regular Air      Home Office        Furniture   Office Furnishings
#
#   Product Container                                       Product Name  \
# 0         Small Box                                         Xerox 1933
# 1         Jumbo Box   Sauder Forest Hills Library, Woodland Oak Finish
# 2         Jumbo Box    Riverside Furniture Stanwyck Manor Table Series
# 3         Small Box  Park Ridge™ Embossed Executive Business Envelopes
# 4        Small Pack  DAX Two-Tone Rosewood/Black Document Frame, De...
#
#    Product Base Margin Region State or Province        City  Postal Code  \
# 0                 0.38   East     Massachusetts  Fall River         2724
# 1                 0.77   East     New Hampshire     Bedford         3110
# 2                 0.78   East        New Jersey      Camden         8101
# 3                 0.38   East        New Jersey  Pennsauken         8109
# 4                 0.45   East        New Jersey     Roselle         7203
#
#   Order Date  Ship Date      Profit  Quantity ordered new    Sales  Order ID  \
# 0 2012-10-30 2012-10-31   72.992800                    19   232.95     90198
# 1 2012-12-25 2012-12-26 -158.740000                     5   705.47     90199
# 2 2012-12-25 2012-12-27 -346.615198                     8  1794.27     90199
# 3 2011-10-04 2011-10-05  142.795500                    14   206.95     90195
# 4 2010-08-15 2010-08-17  -53.809600                    22   211.15     90192
#
#          col_2
# 0   243.309333
# 1  -529.133333
# 2 -1155.383992
# 3   475.985000
# 4  -179.365333

# %% [markdown]
# ## Merge dataframes

# %%
#create 2 dataframe
df1 = df.groupby(['Region', 'Order Date'])[['Sales']].mean().reset_index()
df2 = df.groupby(['Region', 'Order Date'])[['Profit']].mean().reset_index()

# %%
#merge left, use df1.merge(df2, how="left")
df1.merge(df2,how='left')
# Out:
#        Region Order Date        Sales        Profit
# 0     Central 2010-01-02    41.600000    -14.801880
# 1     Central 2010-01-03   105.740000   -157.562460
# 2     Central 2010-01-04   133.686667   -192.447800
# 3     Central 2010-01-05   682.815556    327.719257
# 4     Central 2010-01-06  6968.900000 -13706.464000
# ...       ...        ...          ...           ...
# 3775     West 2013-12-26   123.366667     17.941587
# 3776     West 2013-12-27    22.610000      7.671040
# 3777     West 2013-12-28   311.932500    178.420227
# 3778     West 2013-12-29    91.340000    -55.413120
# 3779     West 2013-12-30   213.005000    -30.581040
#
# [3780 rows x 4 columns]

# %%
#merge on right, use df1.merge(df2, how="right")

# %%
#merging on outer, use df1.merge(df2, how="outer")

# %% [markdown]
# ## Merge suffixes

# %%
#merging using suffices use, pd.merge(df1, df2, on=['col1', 'col2'])

# %%
#merge on specific similar column use pd.merge(df1, df2, on=df['col1'])

# %%
#merging using both letf and right on,use pd.merge(df1, df2, left_on=['col1'], right_on=['col1'])
